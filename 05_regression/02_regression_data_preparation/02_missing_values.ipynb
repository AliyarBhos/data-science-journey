# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, np.nan, 30, 32, 22],
    'Salary': [50000, 60000, np.nan, 52000, np.nan],
    'Department': ['HR', 'IT', 'IT', np.nan, 'Finance']
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %% [markdown]
# #### Types of Missing Values
# * MCAR (Missing Completely at Random) -> Missingness occurs randomly and is not related to any variable in the dataset.
# * MAR (Missing at Random) -> Missingness depends on other observed variables, not on the missing value itself.
# * MNAR (Missing Not at Random) -> Missingness is directly related to the value that is missing.

# %% [markdown]
# #### Methods for detecting Missing data

# %% [markdown]
# ### 1)

# %%
df.isnull()
# Out:
#     Name    Age  Salary  Department
# 0  False  False   False       False
# 1  False   True   False       False
# 2  False  False    True       False
# 3  False  False   False        True
# 4  False  False    True       False

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           1
# Salary        2
# Department    1
# dtype: int64

# %% [markdown]
# ### 2)

# %%
df.notnull()
# Out:
#    Name    Age  Salary  Department
# 0  True   True    True        True
# 1  True  False    True        True
# 2  True   True   False        True
# 3  True   True    True       False
# 4  True   True   False        True

# %%
df.notnull().sum()
# Out:
# Name          5
# Age           4
# Salary        3
# Department    4
# dtype: int64

# %% [markdown]
# ### 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         4 non-null      float64
#  2   Salary      3 non-null      float64
#  3   Department  4 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes

# %% [markdown]
# ### 4)

# %%
df.isna()
# Out:
#     Name    Age  Salary  Department
# 0  False  False   False       False
# 1  False   True   False       False
# 2  False  False    True       False
# 3  False  False   False        True
# 4  False  False    True       False

# %%
df.isna().sum()
# Out:
# Name          0
# Age           1
# Salary        2
# Department    1
# dtype: int64

# %% [markdown]
# ### 5)

# %%
df_copy = df.copy()
df_copy.dropna()
# Out:
#     Name   Age   Salary Department
# 0  Alice  25.0  50000.0         HR

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %% [markdown]
# ### 6)

# %%
df_copy = df.copy()
df_copy.fillna(value='!')
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob     !  60000.0         IT
# 2  Charlie  30.0        !         IT
# 3    David  32.0  52000.0          !
# 4      Eva  22.0        !    Finance

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %% [markdown]
# ### 7)

# %%
df_copy = df.copy()
df_copy.replace(np.nan, '!')
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob     !  60000.0         IT
# 2  Charlie  30.0        !         IT
# 3    David  32.0  52000.0          !
# 4      Eva  22.0        !    Finance

# %% [markdown]
# ### 8)

# %%
df_copy = df.copy()
df_copy.drop_duplicates()
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %% [markdown]
# ### 9)

# %%
df['Age'].unique()
# Out:
# array([25., nan, 30., 32., 22.])

# %%
df['Department'].unique()
# Out:
# array(['HR', 'IT', nan, 'Finance'], dtype=object)

# %%
df['Name'].unique()
# Out:
# array(['Alice', 'Bob', 'Charlie', 'David', 'Eva'], dtype=object)

# %%
df['Salary'].unique()
# Out:
# array([50000., 60000.,    nan, 52000.])

# %% [markdown]
# ### Imputation Methods

# %% [markdown]
# #### 1) Mean, Median and Mode Imputation

# %% [markdown]
# ##### The imputations in these examples are for practice purposes only and do not necessarily reflect real-world usage !!!

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %%
mean_imp = df['Age'].fillna(round(df['Age'].mean(), 0))
median_imp = df['Salary'].fillna(df['Salary'].median())
mode_imp = df['Department'].fillna(df['Department'].mode().iloc[0])

# %%
mean_imp
# Out:
# 0    25.0
# 1    27.0
# 2    30.0
# 3    32.0
# 4    22.0
# Name: Age, dtype: float64

# %%
median_imp
# Out:
# 0    50000.0
# 1    60000.0
# 2    52000.0
# 3    52000.0
# 4    52000.0
# Name: Salary, dtype: float64

# %%
mode_imp
# Out:
# 0         HR
# 1         IT
# 2         IT
# 3         IT
# 4    Finance
# Name: Department, dtype: object

# %% [markdown]
# #### 2) Forward and Backward Fill

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %%
forward_fill = df['Age'].ffill()

# %%
forward_fill
# Out:
# 0    25.0
# 1    25.0
# 2    30.0
# 3    32.0
# 4    22.0
# Name: Age, dtype: float64

# %%
backward_fill = df['Age'].bfill()

# %%
backward_fill
# Out:
# 0    25.0
# 1    30.0
# 2    30.0
# 3    32.0
# 4    22.0
# Name: Age, dtype: float64

# %% [markdown]
# #### 3) Interpolation Techniques

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %%
linear = df['Salary'].interpolate(method='linear')
quadratic = df['Salary'].interpolate(method='quadratic')

# %%
linear
# Out:
# 0    50000.0
# 1    60000.0
# 2    56000.0
# 3    52000.0
# 4    52000.0
# Name: Salary, dtype: float64

# %%
quadratic
# Out:
# 0    50000.000000
# 1    60000.000000
# 2    60666.666667
# 3    52000.000000
# 4             NaN
# Name: Salary, dtype: float64

# %% [markdown]
# ## Sklearn Imputers

# %%
from sklearn.impute import SimpleImputer

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN         IT
# 3    David  32.0  52000.0        NaN
# 4      Eva  22.0      NaN    Finance

# %%
imputer = SimpleImputer(strategy='median')

# %% [markdown]
# #### For now, for the purpose of practice I will try to make X_train and X_test dataframes to only have numeric columns since fitting and transforming without proper pipeline is applied to all columns.

# %%
X_train = df.loc[:4].drop(['Name', 'Department'], axis=1)
X_test = df.loc[4].to_frame().T.drop(['Name', 'Department'], axis=1)

# %%
X_train
# Out:
#     Age   Salary
# 0  25.0  50000.0
# 1   NaN  60000.0
# 2  30.0      NaN
# 3  32.0  52000.0
# 4  22.0      NaN

# %%
X_test
# Out:
#     Age Salary
# 4  22.0    NaN

# %%
train_columns = X_train.columns
train_index = X_train.index

test_columns = X_test.columns
test_index = X_test.index

# %%
train_columns
# Out:
# Index(['Age', 'Salary'], dtype='object')

# %%
train_index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
test_columns
# Out:
# Index(['Age', 'Salary'], dtype='object')

# %%
test_index
# Out:
# Index([4], dtype='int64')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=train_columns, index=train_index)
X_test = pd.DataFrame(X_test, columns=test_columns, index=test_index)

# %%
X_train
# Out:
#     Age   Salary
# 0  25.0  50000.0
# 1  27.5  60000.0
# 2  30.0  52000.0
# 3  32.0  52000.0
# 4  22.0  52000.0

# %%
X_test
# Out:
#     Age   Salary
# 4  22.0  52000.0
