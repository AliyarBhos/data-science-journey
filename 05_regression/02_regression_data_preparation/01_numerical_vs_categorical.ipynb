# %%
import numpy as np

# %%
ages = np.array([25, 27, 21, 23])
ages.dtype
# Out:
# dtype('int64')

# %%
cities = np.array(['Edinburg', 'Milan', 'Tehran', 'New Dehli'])
cities.dtype
# Out:
# dtype('<U9')

# %%
ids = np.array([1, 'a', 2, 'b'])
ids.dtype
# Out:
# dtype('<U21')

# %% [markdown]
# ##### Whether a variable is numerical or categorical depends on what the values mean, not merely on their Python/NumPy dtype.
