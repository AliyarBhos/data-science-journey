# %%
w = 5.0
learning_rate = 0.1
iterations = 20

# %%
for i in range(iterations):
    gradient = 2 * w
    w = w - learning_rate * gradient
    loss = w ** 2

    print(f'Iteration {i + 1}: w = {w:.4f}, loss = {loss:.4f}')
# Out:
# Iteration 1: w = 4.0000, loss = 16.0000
# Iteration 2: w = 3.2000, loss = 10.2400
# Iteration 3: w = 2.5600, loss = 6.5536
# Iteration 4: w = 2.0480, loss = 4.1943
# Iteration 5: w = 1.6384, loss = 2.6844
# Iteration 6: w = 1.3107, loss = 1.7180
# Iteration 7: w = 1.0486, loss = 1.0995
# Iteration 8: w = 0.8389, loss = 0.7037
# Iteration 9: w = 0.6711, loss = 0.4504
# Iteration 10: w = 0.5369, loss = 0.2882
# Iteration 11: w = 0.4295, loss = 0.1845
# Iteration 12: w = 0.3436, loss = 0.1181
# Iteration 13: w = 0.2749, loss = 0.0756
# Iteration 14: w = 0.2199, loss = 0.0484
# Iteration 15: w = 0.1759, loss = 0.0309
# Iteration 16: w = 0.1407, loss = 0.0198
# Iteration 17: w = 0.1126, loss = 0.0127
# Iteration 18: w = 0.0901, loss = 0.0081
# Iteration 19: w = 0.0721, loss = 0.0052
# Iteration 20: w = 0.0576, loss = 0.0033
